# %%
#Import required libraries
import pandas as pd

# %%
data  = pd.read_csv('raw_data.csv')

# %%
data.head(50)
# Out:
#     Unnamed: 0  pos               artist_name  \
# 0            0    0             Missy Elliott
# 1            1    1            Britney Spears
# 2            2    2                   Beyoncé
# 3            3    3         Justin Timberlake
# 4            4    4                    Shaggy
# 5            5    5                     Usher
# 6            6    6                     Usher
# 7            7    7        The Pussycat Dolls
# 8            8    8           Destiny's Child
# 9            9    9                   OutKast
# 10          10   10             Nelly Furtado
# 11          11   11           Jesse McCartney
# 12          12   12           Jesse McCartney
# 13          13   13           Jesse McCartney
# 14          14   14                    Cassie
# 15          15   15                   Omarion
# 16          16   16             Avril Lavigne
# 17          17   17               Chris Brown
# 18          18   18                   Beyoncé
# ...

# %%
print("Length of the dataframe:", len(data))
# Out:
# Length of the dataframe: 67503

# %%
data[data['name']=='Throwbacks']
# Out:
#        Unnamed: 0  pos        artist_name  \
# 0               0    0      Missy Elliott
# 1               1    1     Britney Spears
# 2               2    2            Beyoncé
# 3               3    3  Justin Timberlake
# 4               4    4             Shaggy
# ...           ...  ...                ...
# 60334       60334  132            50 Cent
# 60335       60335  133      4 Non Blondes
# 60336       60336  134  Melissa Etheridge
# 60337       60337  135            50 Cent
# 60338       60338  136              Wham!
#
#                                   track_uri  \
# 0      spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1      spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2      spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3      spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4      spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...                                     ...
# 60334  spotify:track:4nva9EpKntUTs6CRSGBCn9
# 60335  spotify:track:7f0jXNMu2xjQUtmKMuWhGA
# 60336  spotify:track:4veE1jrMbVSy9FRCiYDGkD
# ...

# %%
data['name'].value_counts()
# Out:
# Country                1741
# rap                     578
# Gym                     441
# Worship                 424
# Rock                    413
#                        ...
# oldies but goodies        5
# MY FAV                    5
# dank memes                5
# shower                    5
# Shower                    5
# Name: name, Length: 869, dtype: int64

# %%
data[data['name'] == 'Country']
# Out:
#        Unnamed: 0  pos       artist_name  \
# 2148         2148    0        Luke Bryan
# 2149         2149    1        Luke Bryan
# 2150         2150    2        Luke Bryan
# 2151         2151    3        Luke Bryan
# 2152         2152    4        Luke Bryan
# ...           ...  ...               ...
# 67454       67454  103    Dierks Bentley
# 67455       67455  104  Carrie Underwood
# 67456       67456  105          Kid Rock
# 67457       67457  106    Brett Eldredge
# 67458       67458  107       Brett Young
#
#                                   track_uri  \
# 2148   spotify:track:1PoGWZbJPGmViVi7CYbDUK
# 2149   spotify:track:6GBUsjHfZuweYf5lQEz6mP
# 2150   spotify:track:0yD66650JxhqKbW76C2qCo
# 2151   spotify:track:3b7CDTKB0SRTmQ6ytYi5vZ
# 2152   spotify:track:5HGibWoxnkYSkl6mHmAlOE
# ...                                     ...
# 67454  spotify:track:5HJId22hZ2IvFnvNSy6ZbE
# 67455  spotify:track:0d0tJF80562KcMndcBcSfM
# 67456  spotify:track:69j0KoPJuwpnbGWrfn7Yll
# ...
